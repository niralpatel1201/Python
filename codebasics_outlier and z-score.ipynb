# %%
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats

# %%
df = pd.read_csv('weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.Weight.describe()
# Out:
# count    10000.000000
# mean       161.440357
# std         32.108439
# min         64.700127
# 25%        135.818051
# 50%        161.212928
# 75%        187.169525
# max        269.989699
# Name: Weight, dtype: float64

# %%
sn.histplot(df.Weight, kde = True)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
sn.histplot(df.Height, kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
mean = df.Height.mean()
print(mean)
# Out:
# 66.36755975482124

# %%
std = df.Height.std()
print(std)
# Out:
# 3.8475281207732293

# %%
mean - 3*3.84758
# Out:
# np.float64(54.82481975482125)

# %%
mean + 3*3.4758
# Out:
# np.float64(76.79495975482125)

# %%
outlier  = df[(df.Height < 54.82481975482125) |  (df.Height > 76.79495975482125) ]
outlier
outlier.shape
# Out:
# (18, 3)

# %%
no_outlier = df[(df.Height > 54.82481975482125) &  (df.Height < 76.79495975482125) ]
no_outlier
no_outlier.shape
# Out:
# (9982, 3)

# %%
df['z_score'] = (df.Height-df.Height.mean())/df.Height.std()

# %%
df.head()
# Out:
#   Gender     Height      Weight   z_score
# 0   Male  73.847017  241.893563  1.943964
# 1   Male  68.781904  162.310473  0.627505
# 2   Male  74.110105  212.740856  2.012343
# 3   Male  71.730978  220.042470  1.393991
# 4   Male  69.881796  206.349801  0.913375

# %%
df[df.z_score<-3]
# Out:
#       Gender     Height     Weight   z_score
# 6624  Female  54.616858  71.393749 -3.054091
# 9285  Female  54.263133  64.700127 -3.146027

# %%
df[df.z_score>3]
# Out:
#      Gender     Height      Weight   z_score
# 994    Male  78.095867  255.690835  3.048271
# 1317   Male  78.462053  227.342565  3.143445
# 2014   Male  78.998742  269.989699  3.282934
# 3285   Male  78.528210  253.889004  3.160640
# 3757   Male  78.621374  245.733783  3.184854

# %%
df.Height.median()
# Out:
# np.float64(66.31807008178464)

# %%
stats.zscore(df.Height)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 stats.zscore(['z_score'], df.Height)
#
# File c:\Users\niral\Desktop\Python\.venv\Lib\site-packages\scipy\stats\_stats_py.py:2992, in zscore(a, axis, ddof, nan_policy)
#    2910 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2911     """
#    2912     Compute the z score.
#    2913
#    (...)
#    2990            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2991     """
# -> 2992     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File c:\Users\niral\Desktop\Python\.venv\Lib\site-packages\scipy\stats\_stats_py.py:3156, in zmap(scores, compare, axis, ddof, nan_policy)
#    3154         isconst = np.apply_along_axis(_isconst, axis, a)
#    3155 else:
# -> 3156     mn = a.mean(axis=axis, keepdims=True)
# ...

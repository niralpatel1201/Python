# %% [markdown]
# Exercise
# You are given bhp.csv which contains property prices in the city of banglore, India. You need to examine price_per_sqft column and do following,
#
# (1) Remove outliers using percentile technique first. Use [0.001, 0.999] for lower and upper bound percentiles
#
# (2) After removing outliers in step 1, you get a new dataframe.
#
# (3) On step(2) dataframe, use 4 standard deviation to remove outliers
#
# (4) Plot histogram for new dataframe that is generated after step (3). Also plot bell curve on same histogram
#
# (5) On step(2) dataframe, use zscore of 4 to remove outliers. This is quite similar to step (3) and you will get exact same result

# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
df = pd.read_csv('bhp.csv')
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.shape
# Out:
# (13200, 7)

# %%
lower = df.price_per_sqft.quantile(0.001)

# %%
higher = df.price_per_sqft.quantile(0.999)

# %%
outlier = df[(df.price_per_sqft<lower) | (df.price_per_sqft>higher)]
outlier
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 665            Yelahanka      3 BHK     35000.0   3.0   130.0    3
# 798                other  4 Bedroom     10961.0   4.0    80.0    4
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 1867               other  3 Bedroom     52272.0   2.0   140.0    3
# 2392               other  4 Bedroom      2000.0   3.0    25.0    4
# 3934               other      1 BHK      1500.0   1.0    19.5    1
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5343               other      9 BHK     42000.0   8.0   175.0    9
# 5417              Ulsoor      4 BHK     36000.0   4.0   450.0    4
# 5597            JP Nagar      2 BHK      1100.0   1.0    15.0    2
# ...

# %%
no_outlier = df[(df.price_per_sqft>lower) & (df.price_per_sqft<higher)]
no_outlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
mean = no_outlier.price_per_sqft.mean()
print(mean)
# Out:
# 6663.6537351958705

# %%
std = no_outlier.price_per_sqft.std()
print(std)
# Out:
# 4141.020700174613

# %%
print(mean - 4*std)
# Out:
# -9900.429065502582

# %%
print(mean + 4*std)
# Out:
# 23227.73653589432

# %%
new_df = no_outlier[(no_outlier.price_per_sqft>lower) & (no_outlier.price_per_sqft<higher)]

# %%
sn.histplot(new_df.price_per_sqft, kde=True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
new_df['z_score'] = (new_df.price_per_sqft-new_df.price_per_sqft.mean())/new_df.price_per_sqft.std()

# %%
new_df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft   z_score
# 0            3699 -0.715923
# 1            4615 -0.494722
# 2            4305 -0.569583
# 3            6245 -0.101099
# 4            4250 -0.582864

# %%
new_df[new_df.z_score > 4]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft   z_score
# 9               36274  7.150495
# 45              33333  6.440283
# 190             27083  4.930994
# 733             23719  4.118633
# ...

# %%
new_df[new_df.z_score <-4]
# Out:
# Empty DataFrame
# Columns: [location, size, total_sqft, bath, price, bhk, price_per_sqft, z_score]
# Index: []

# %%
final_outliers = new_df[(new_df.z_score > 4) | (new_df.z_score < -4)]

# %%
final_outliers
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft   z_score
# 9               36274  7.150495
# 45              33333  6.440283
# 190             27083  4.930994
# 733             23719  4.118633
# ...

# %%
final_df = new_df[(new_df.z_score < 4) & (new_df.z_score > -4)]

# %%
final_df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft   z_score
# 0                3699 -0.715923
# ...

# %%
final_df.shape
# Out:
# (13047, 8)
